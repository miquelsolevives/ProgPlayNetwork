# %%
pip install ipympl

# %%
pip install mplsoccer

# %%
pip install statsbombpy

# %%
# !git clone "https://github.com/miquelsolevives/ProgPlayNetwork.git"

# %%
pip install ProgPlayNetwork/progplaynetwork-0.12.tar.gz

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %%
# %matplotlib ipympl
import matplotlib.pyplot as plt
from progplaynetwork import wc_PPN as ppn_wc

# if __name__ == "__main__":
plt.close('all')
plt.ion()
ppn_wc.wc_PPN()
